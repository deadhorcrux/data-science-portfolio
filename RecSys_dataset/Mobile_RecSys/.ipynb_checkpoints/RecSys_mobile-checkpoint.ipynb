# %%
import pandas as pd
import numpy as np 

from surprise import Reader, Dataset, SVD
from surprise.model_selection import cross_validate
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity

import warnings; warnings.simplefilter('ignore')

# %%
df = pd.read_csv('./Mobile_dataset/mobile_recommendation_system_dataset.csv')

# %%
df.head()
# Out:
#                                         name  ratings    price
# 0  REDMI Note 12 Pro 5G (Onyx Black, 128 GB)      4.2    23999  \
# 1        OPPO F11 Pro (Aurora Green, 128 GB)      4.5  ₹20,999
# 2     REDMI Note 11 (Starburst White, 64 GB)      4.2    13149
# 3     OnePlus Nord CE 5G (Blue Void, 256 GB)      4.1    21999
# 4        APPLE iPhone 13 mini (Blue, 128 GB)      4.6     3537
#
#                                               imgURL
# 0  https://rukminim2.flixcart.com/image/312/312/x...  \
# 1  https://rukminim2.flixcart.com/image/312/312/k...
# 2  https://rukminim2.flixcart.com/image/312/312/x...
# 3  https://rukminim2.flixcart.com/image/312/312/x...
# 4  https://rukminim2.flixcart.com/image/312/312/k...
#
#                                               corpus
# 0  Storage128 GBRAM6  SystemAndroid 12Processor T...
# 1  Storage128 GBRAM6 GBExpandable Storage256GB  S...
# 2  Storage64 GBRAM4  SystemAndroid 11Processor Sp...
# 3  Storage256 GBRAM12  SystemAndroid Q 11Processo...
# 4  Storage128  SystemiOS 15Processor TypeA15 Bion...

# %%
tmp = df.copy()

# %%
tmp['price'] = tmp['price'].str.replace(r"[^\d\.]", "", regex=True)

# %%
tmp['price'] = tmp['price'].astype('float64')

# %%
tmp['corpus'] = tmp['corpus'].str.lower()

# %%
import re

def extract_storage(corpus):
    match = re.search(r'storage(\d+)', corpus)
    if match:
        return int(match.group(1))
    return None

# Apply the function to the 'corpus' column
tmp['storage'] = tmp['corpus'].apply(extract_storage)

# %%
def extract_ram(corpus):
    """Extract the RAM from the corpus."""
    match = re.search(r'ram(\d+)', corpus)
    if match:
        return int(match.group(1))
    return None

def extract_system(corpus):
    """Extract the operating system from the corpus."""
    match = re.search(r'system(.*?)processor', corpus)
    if match:
        return match.group(1).strip()
    return None

def extract_processor(corpus):
    """Extract the processor type from the corpus."""
    match = re.search(r'processor (.*?) ', corpus)
    if match:
        return match.group(1).strip()
    return None

# %%
tmp['ram'] = tmp['corpus'].apply(extract_ram)
tmp['system'] = tmp['corpus'].apply(extract_system)
tmp['processor'] = tmp['corpus'].apply(extract_processor)

# %%
tmp.isnull().sum()
# Out:
# name        0
# ratings     0
# price       0
# imgURL      0
# corpus     12
# dtype: int64

# %%
tmp = tmp.dropna()

# %%
df = tmp.copy()

# %%
tf = TfidfVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(df['corpus'])

# %%
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# %%
cosine_sim
# Out:
# array([[1.        , 0.04786072, 0.0884595 , ..., 0.05959329, 0.03551622,
#         0.16817265],
#        [0.04786072, 1.        , 0.0132211 , ..., 0.05689957, 0.00488636,
#         0.03936838],
#        [0.0884595 , 0.0132211 , 1.        , ..., 0.30769847, 0.01731517,
#         0.09351258],
#        ...,
#        [0.05959329, 0.05689957, 0.30769847, ..., 1.        , 0.01331809,
#         0.050823  ],
#        [0.03551622, 0.00488636, 0.01731517, ..., 0.01331809, 1.        ,
#         0.03058663],
#        [0.16817265, 0.03936838, 0.09351258, ..., 0.050823  , 0.03058663,
#         1.        ]])

# %%
list(enumerate(cosine_sim[0]))[:5]
# Out:
# [(0, 1.0000000000000002),
#  (1, 0.04786071843668162),
#  (2, 0.08845950104082932),
#  (3, 0.046522460951568576),
#  (4, 0.05194747068286624)]

# %%
df = df.reset_index()
names = df['name']
indices = pd.Series(df.index, index=df['name'])

# %%
def get_recommendations(name):
    idx = indices[name]
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:31]
    name_indices = [i[0] for i in sim_scores]
    simple_rec = df.iloc[name_indices][['name', 'ratings', 'price']]
    simple_rec['wr'] = simple_rec['price']/simple_rec['ratings']
    return simple_rec.sort_values('wr', ascending=True)

# %%
get_recommendations(df['name'][0])
# Out:
#                                                    name  ratings    price
# 68       REDMI Note 12 Pro 5G (Stardust Purple, 128 GB)      4.2  23999.0
# 303         REDMI Note 12 Pro 5G (Glacier Blue, 128 GB)      4.2  23999.0
# 616      REDMI Note 12 Pro 5G (Stardust Purple, 128 GB)      4.2  24999.0
# 1461        REDMI Note 12 Pro 5G (Glacier Blue, 128 GB)      4.2  24999.0
# 457           REDMI Note 12 Pro 5G (Onyx Black, 256 GB)      4.2  26999.0
# 1027     REDMI Note 12 Pro 5G (Stardust Purple, 256 GB)      4.2  26999.0
# 1735        REDMI Note 12 Pro 5G (Glacier Blue, 256 GB)      4.2  26999.0
# 569        REDMI Note 12 Pro+ 5G (Arctic White, 256 GB)      4.2  29999.0
# 1123       REDMI Note 12 Pro+ 5G (Arctic White, 256 GB)      4.2  32537.0
# 1540       REDMI Note 12 Pro+ 5G (Iceberg Blue, 256 GB)      4.2  32537.0
# 257   Xiaomi 11i Hypercharge 5G (Pacific Pearl, 128 GB)      4.2  23999.0
# 528      Xiaomi 11i Hypercharge 5G (Camo Green, 128 GB)      4.2  23999.0
# 2048  Xiaomi 11i Hypercharge 5G (Stealth Black, 128 GB)      4.2  23999.0
# 142   Xiaomi 11i Hypercharge 5G (Pacific Pearl, 128 GB)      4.2  28999.0
# 437   Xiaomi 11i Hypercharge 5G (Stealth Black, 128 GB)      4.2  28999.0
# 673                 Xiaomi 11i 5G (Purple Mist, 128 GB)      4.2  24999.0
# 1417                 Xiaomi 11i 5G (Camo Green, 128 GB)      4.2  24999.0
# 2163              Xiaomi 11i 5G (Stealth Black, 128 GB)      4.2  24999.0
# 534               Xiaomi 11i 5G (Pacific Pearl, 128 GB)      4.2  26999.0
# 1066                Xiaomi 11i 5G (Purple Mist, 128 GB)      4.2  26999.0
# 1418                 Xiaomi 11i 5G (Camo Green, 128 GB)      4.2  26999.0
# 2355              Xiaomi 11i 5G (Stealth Black, 128 GB)      4.2  26999.0
# 1388            realme 9 Pro+ 5G (Sunrise Blue, 128 GB)      4.4  26999.0
# 2109            realme 9 Pro+ 5G (Aurora Green, 256 GB)      4.4  28999.0
# 1675            realme 9 Pro+ 5G (Aurora Green, 128 GB)      4.3  24999.0
# 943                vivo V23e 5G (Sunshine Gold, 128 GB)      4.2  24999.0
# 1481               vivo V23e 5G (Sunshine Gold, 128 GB)      4.5  23900.0
# 1791               vivo V23e 5G (Midnight Blue, 128 GB)      4.3  24999.0
# 2320               vivo V23e 5G (Midnight Blue, 128 GB)      4.2  24999.0
# 531                REDMI Note 12 (Sunrise Gold, 128 GB)      4.1  15999.0

# 2109  6590.681818
# 142   6904.523810
# 437   6904.523810
# 569   7142.619048
# 1540  7746.904762
# 1123  7746.904762

# %%
get_recommendations('APPLE iPhone 13 mini (Blue, 128 GB)')
# Out:
#                                              name  ratings    price
# 429   APPLE iPhone 13 mini ((PRODUCT)RED, 128 GB)      4.7   3537.0  \
# 2199           APPLE iPhone 13 (Midnight, 128 GB)      4.7   3537.0
# 2142              APPLE iPhone 13 (Green, 128 GB)      4.7   3537.0
# 1719       APPLE iPhone 13 ((PRODUCT)RED, 128 GB)      4.7   3537.0
# 1243          APPLE iPhone 13 (Starlight, 128 GB)      4.7   3537.0
# 832                APPLE iPhone 13 (Blue, 128 GB)      4.7   3537.0
# 1366         APPLE iPhone 13 mini (Green, 128 GB)      4.7   3537.0
# 207       APPLE iPhone 13 mini (Midnight, 128 GB)      4.5   3537.0
# 720      APPLE iPhone 13 mini (Starlight, 128 GB)      4.5   3537.0
# 2295          APPLE iPhone 13 mini (Pink, 128 GB)      4.4   3537.0
# 1940  APPLE iPhone 13 mini ((PRODUCT)RED, 256 GB)      4.7   6463.0
# 2092          APPLE iPhone 13 mini (Blue, 256 GB)      4.7   6463.0
# 2519               APPLE iPhone 13 (Pink, 256 GB)      4.7   6463.0
# 1798               APPLE iPhone 13 (Blue, 256 GB)      4.7   6463.0
# 1426          APPLE iPhone 13 (Starlight, 256 GB)      4.7   6463.0
# 177        APPLE iPhone 13 ((PRODUCT)RED, 256 GB)      4.7   6463.0
# 1233     APPLE iPhone 13 mini (Starlight, 256 GB)      4.7   6463.0
# 1374          APPLE iPhone 13 mini (Pink, 256 GB)      4.5   6463.0
# 540      APPLE iPhone 13 mini (Starlight, 256 GB)      4.5   6463.0
# 1290      APPLE iPhone 13 mini (Midnight, 256 GB)      4.5   6463.0
# 676          APPLE iPhone 13 mini (Green, 256 GB)      4.5   6463.0
# 2186     APPLE iPhone 13 mini (Starlight, 512 GB)      4.6  24463.0
# 919           APPLE iPhone 13 mini (Pink, 512 GB)      4.6  24463.0
# 817       APPLE iPhone 13 mini (Midnight, 512 GB)      4.6  24463.0
# 1790          APPLE iPhone 13 mini (Blue, 512 GB)      4.5  24463.0
# 773               APPLE iPhone 13 (Green, 512 GB)      4.7  26463.0
# 905           APPLE iPhone 13 (Starlight, 512 GB)      4.7  26463.0
# 1244               APPLE iPhone 13 (Blue, 512 GB)      4.7  26463.0
# 1542           APPLE iPhone 13 (Midnight, 512 GB)      4.7  26463.0
# 2413               APPLE iPhone 13 (Pink, 512 GB)      4.5  26463.0
#
#                wr
# 429    752.553191
# 2199   752.553191
# 2142   752.553191
# 1719   752.553191
# 1243   752.553191
# 832    752.553191
# 1366   752.553191
# 207    786.000000
# 720    786.000000
# 2295   803.863636
# 1940  1375.106383
# 2092  1375.106383
# 2519  1375.106383
# 1798  1375.106383
# 1426  1375.106383
# 177   1375.106383
# 1233  1375.106383
# 1374  1436.222222
# 540   1436.222222
# 1290  1436.222222
# 676   1436.222222
# 2186  5318.043478
# 919   5318.043478
# 817   5318.043478
# 1790  5436.222222
# 773   5630.425532
# 905   5630.425532
# 1244  5630.425532
# 1542  5630.425532
# 2413  5880.666667
